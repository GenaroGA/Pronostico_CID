# %% [markdown]
# ## Análisis previo

# %% [markdown]
# Importación de datos

# %%
library(readxl)
Prestamos_CID <- read_excel("Datos/Prestamos_Devoluciones_CID.xlsx",sheet = "Prestamos2019")
Devoluciones_CID <- read_excel("Datos/Prestamos_Devoluciones_CID.xlsx",sheet = "Devoluciones2019")

# %% [markdown]
# ## Graficas

# %% [markdown]
# ### Graficación de los datos

# %%
plot(Prestamos_CID,type='l')
plot(Devoluciones_CID,type='l')
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### ACFs

# %%
acf(Prestamos_CID$cnt,plot ='true',lag.max=100000)
acf(Devoluciones_CID$cnt,plot ='true',lag.max=100000)
# Out:
# Plot with title “Series  Prestamos_CID$cnt”
# Plot with title “Series  Devoluciones_CID$cnt”

# %% [markdown]
# ### PACFs

# %%
pacf(Prestamos_CID$cnt,plot ='true',lag.max=100000)
pacf(Devoluciones_CID$cnt,plot ='true',lag.max=100000)
# Out:
# Plot with title “Series  Prestamos_CID$cnt”
# Plot with title “Series  Devoluciones_CID$cnt”

# %% [markdown]
# ### Periodograma

# %%
#install.packages("descomponer")
library("descomponer")
gperiodograma(Prestamos_CID$cnt)
# Out:
# Plot with title “Espectro”

# %%
gperiodograma(Devoluciones_CID$cnt)
# Out:
# Plot with title “Espectro”

# %% [markdown]
# ### Periodograma Integrado

# %%
library('TSA')
periodograma_prestamos <-periodogram(Prestamos_CID$cnt,log='yes',plot='true')
plot(periodograma_prestamos)
# Out:
# Attaching package: ‘TSA’
#
#
# The following objects are masked from ‘package:stats’:
#
#     acf, arima
#
#
# The following object is masked from ‘package:utils’:
#
#     tar
# Plot with title “Series: x
# Raw Periodogram”

# %%
periodograma_devoluciones <-periodogram(Devoluciones_CID$cnt,log='yes',plot='true')
plot(periodograma_devoluciones)
# Out:
# Plot with title “Series: x
# Raw Periodogram”
